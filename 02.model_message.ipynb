# %% [markdown]
# # Openai api key

# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.environ["OPENAI_API_KEY"]
# api_key

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    api_key=api_key,
    model="gpt-4o"
    )

# %% [markdown]
# - langchain ChatOpenAI() 객체를 통해 질문하기

# %%
messages = [
    ("system", "당신은 서울의 음시과 문화 전문가 입니다."),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.")
]

res = llm.invoke(messages)

# %%
print(res.content)
# Out:
# 서울에는 다양한 한식 레스토랑이 있지만, 서울을 대표하는 음식을 맛볼 수 있는 몇 가지 특별한 장소를 추천드립니다.
#
# 1. **명동교자** - 여기서는 한국의 전통 칼국수를 맛볼 수 있습니다. 쫄깃한 면발과 깊은 맛의 육수가 일품이며, 손맛이 느껴지는 만두도 함께 맛보실 수 있습니다.
#
# 2. **광장시장** - 비록 레스토랑이라기보다는 전통 시장이지만, 한국의 여러 길거리 음식을 한 곳에서 즐길 수 있는 곳입니다. 특히 마약김밥, 빈대떡, 육회 비빔밥 등이 유명합니다.
#
# 3. **한양집** - 성북구에 위치한 한양집은 한국의 전통 불고기를 맛볼 수 있는 곳입니다. 불판에 직접 구워먹는 불고기와 함께 다양한 반찬이 제공됩니다.
#
# 4. **뚝심** - 용산에 있는 이 식당은 한우 설렁탕으로 유명합니다. 담백하면서도 진한 국물 맛이 일품이며, 한국식 고급 소고기 전골을 경험할 수 있는 곳입니다.
#
# 5. **윤가네 전주비빔밥** - 이곳은 비빔밥으로 유명한 레스토랑으로, 신선한 재료와 고소한 참기름의 조화가 훌륭합니다. 특히 전주 지역의 전통 방식으로 비빔밥을 조리하여 한국의 대표적인 비빔밥 맛을 느낄 수 있습니다.
#
# 이 외에도 서울에서는 다양한 한식당에서 한국 전통 음식을 즐길 수 있습니다. 명성이 있는 레스토랑 외에도 작은 골목이나 시장에서 찾을 수 있는 숨은 맛집들도 많으니 새로운 곳을 탐방해보는 것도 좋습니다.

# %% [markdown]
# ## batch 처리

# %%
messages = [
    [("system", "당신은 서울의 음식 전문가입니다."), 
        ("human", "서울 광장시장에서 먹을 만한 길거리 음식들을 소개해 주세요")],
    [("system", "당신은 서울의 문화 전문가입니다."), 
         ("human", "서울에서 데이트할 때 가 볼 만한 분위기 좋은 곳들을 알려 주세요")] 
]

responses = llm.batch(messages)

# %%
responses.content
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 responses.content
#
# AttributeError: 'list' object has no attribute 'content'

# %%
responses
# Out:
# [AIMessage(content='서울 광장시장은 다양한 길거리 음식으로 유명한 장소입니다. 여기서는 한국 전통 음식부터 현대적인 스낵까지 다양한 음식을 즐길 수 있습니다. 몇 가지 추천드릴 만한 음식을 소개하겠습니다.\n\n1. **빈대떡**: 녹두를 갈아 만든 전으로, 고소하고 바삭한 맛이 일품입니다. 광장시장에서 가장 유명한 음식 중 하나입니다.\n\n2. **마약김밥**: 작은 크기의 김밥으로, 달콤한 겨자 소스와 함께 제공되어 계속해서 손이 가게 됩니다.\n\n3. **누룽지닭강정**: 닭강정을 바삭하게 튀긴 후 매콤달콤한 소스를 입힌 스낵으로, 입맛을 돋우기 좋은 간식입니다.\n\n4. **떡볶이**: 매콤하고 쫄깃한 떡볶이는 한국 길거리 음식의 대표주자입니다. 광장시장에서는 다양한 형태의 떡볶이를 맛볼 수 있습니다.\n\n5. **호떡**: 달콤한 설탕 시럽과 견과류가 들어간 호떡은 겨울철에 특히 인기가 많습니다.\n\n6. **순대**: 돼지의 소창에 당면과 야채 등을 채워 만든 한국식 소시지로, 쫄깃한 식감이 특징입니다.\n\n7. **김치전**: 김치를 듬뿍 넣어 만든 전으로, 매콤한 맛과 바삭한 식감이 잘 어울립니다.\n\n각 음식은 시장의 다양한 포장마차에서 제공되며, 가성비 좋고 푸짐한 양을 자랑합니다. 방문하시면 시장의 활기찬 분위기와 함께 다양한 음식을 즐겨보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 401, 'prompt_tokens': 36, 'total_tokens': 437, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BfhsLsHiylMjWeCLTQG2xV8zWMb1u', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--0f524715-3c39-4d44-be54-becac0ca1b24-0', usage_metadata={'input_tokens': 36, 'output_tokens': 401, 'total_tokens': 437, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='서울에는 데이트하기 좋은 분위기 좋은 장소들이 많이 있습니다. 여기 몇 가지 추천드릴게요:\n\n1. **한강공원**: 서울에서 가장 유명한 야외 공간 중 하나로, 강변을 따라 산책하거나 자전거를 탈 수 있습니다. 저녁에는 야경을 감상하며 도시의 불빛을 즐길 수 있습니다.\n\n2. **북촌한옥마을**: 전통 한옥과 골목길이 매력적인 곳으로, 산책하며 전통과 현대가 공존하는 분위기를 느낄 수 있습니다. 카페나 작은 갤러리도 들러보세요.\n\n3. **남산서울타워**: 서울의 상징 중 하나인 남산타워에서는 도시 전경을 한눈에 볼 수 있습니다. 케이블카를 타고 올라가는 것도 재미있는 경험이 될 것입니다.\n\n4. **가로수길**: 신사동에 위치한 가로수길은 세련된 분위기의 카페와 패션 숍이 많아 데이트하기 좋은 장소입니다. 트렌디한 식당에서 맛있는 식사를 즐겨보세요.\n\n5. **창덕궁 후원**: 고즈넉한 분위기의 창덕궁 후원은 한국 전통 정원의 아름다움을 만끽할 수 있는 곳입니다. 가이드 투어를 예약하면 더욱 깊이 있는 관람이 가능합니다.\n\n6. **이태원**: 다양한 문화가 공존하는 이태원은 이국적인 음식점과 바들이 즐비해 있습니다. 색다른 분위기에서 저녁을 보내기에 좋습니다.\n\n7. **삼청동**: 예쁜 카페와 아기자기한 상점들이 늘어서 있는 삼청동은 산책하며 즐기기에 알맞습니다. 아트 갤러리나 작은 공방도 많아 볼거리가 풍부합니다.\n\n8. **남대문시장 야시장**: 전통 시장의 활기찬 분위기를 느끼며 다양한 길거리 음식을 즐길 수 있는 곳입니다. 밤에는 더욱 매력적인 장관을 제공합니다.\n\n이 외에도 서울에는 많은 숨겨진 명소들이 있으니 서로의 취향에 맞게 다양한 장소들을 시도해 보세요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 480, 'prompt_tokens': 37, 'total_tokens': 517, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a288987b44', 'id': 'chatcmpl-BfhsLei5XK2z7YgCpS3i18h1eDJwg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--c9f2c858-9afe-4675-b1de-1ea304febd99-0', usage_metadata={'input_tokens': 37, 'output_tokens': 480, 'total_tokens': 517, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
for i, res in enumerate(responses):
    print(f"Response {i+1}: {res.content}")
    print("-" * 50)
# Out:
# Response 1: 서울 광장시장은 다양한 길거리 음식으로 유명한 장소입니다. 여기서는 한국 전통 음식부터 현대적인 스낵까지 다양한 음식을 즐길 수 있습니다. 몇 가지 추천드릴 만한 음식을 소개하겠습니다.
#
# 1. **빈대떡**: 녹두를 갈아 만든 전으로, 고소하고 바삭한 맛이 일품입니다. 광장시장에서 가장 유명한 음식 중 하나입니다.
#
# 2. **마약김밥**: 작은 크기의 김밥으로, 달콤한 겨자 소스와 함께 제공되어 계속해서 손이 가게 됩니다.
#
# 3. **누룽지닭강정**: 닭강정을 바삭하게 튀긴 후 매콤달콤한 소스를 입힌 스낵으로, 입맛을 돋우기 좋은 간식입니다.
#
# 4. **떡볶이**: 매콤하고 쫄깃한 떡볶이는 한국 길거리 음식의 대표주자입니다. 광장시장에서는 다양한 형태의 떡볶이를 맛볼 수 있습니다.
#
# 5. **호떡**: 달콤한 설탕 시럽과 견과류가 들어간 호떡은 겨울철에 특히 인기가 많습니다.
#
# 6. **순대**: 돼지의 소창에 당면과 야채 등을 채워 만든 한국식 소시지로, 쫄깃한 식감이 특징입니다.
#
# 7. **김치전**: 김치를 듬뿍 넣어 만든 전으로, 매콤한 맛과 바삭한 식감이 잘 어울립니다.
#
# 각 음식은 시장의 다양한 포장마차에서 제공되며, 가성비 좋고 푸짐한 양을 자랑합니다. 방문하시면 시장의 활기찬 분위기와 함께 다양한 음식을 즐겨보세요!
# --------------------------------------------------
# Response 2: 서울에는 데이트하기 좋은 분위기 좋은 장소들이 많이 있습니다. 여기 몇 가지 추천드릴게요:
#
# 1. **한강공원**: 서울에서 가장 유명한 야외 공간 중 하나로, 강변을 따라 산책하거나 자전거를 탈 수 있습니다. 저녁에는 야경을 감상하며 도시의 불빛을 즐길 수 있습니다.
#
# 2. **북촌한옥마을**: 전통 한옥과 골목길이 매력적인 곳으로, 산책하며 전통과 현대가 공존하는 분위기를 느낄 수 있습니다. 카페나 작은 갤러리도 들러보세요.
#
# 3. **남산서울타워**: 서울의 상징 중 하나인 남산타워에서는 도시 전경을 한눈에 볼 수 있습니다. 케이블카를 타고 올라가는 것도 재미있는 경험이 될 것입니다.
#
# 4. **가로수길**: 신사동에 위치한 가로수길은 세련된 분위기의 카페와 패션 숍이 많아 데이트하기 좋은 장소입니다. 트렌디한 식당에서 맛있는 식사를 즐겨보세요.
#
# 5. **창덕궁 후원**: 고즈넉한 분위기의 창덕궁 후원은 한국 전통 정원의 아름다움을 만끽할 수 있는 곳입니다. 가이드 투어를 예약하면 더욱 깊이 있는 관람이 가능합니다.
#
# 6. **이태원**: 다양한 문화가 공존하는 이태원은 이국적인 음식점과 바들이 즐비해 있습니다. 색다른 분위기에서 저녁을 보내기에 좋습니다.
#
# 7. **삼청동**: 예쁜 카페와 아기자기한 상점들이 늘어서 있는 삼청동은 산책하며 즐기기에 알맞습니다. 아트 갤러리나 작은 공방도 많아 볼거리가 풍부합니다.
#
# 8. **남대문시장 야시장**: 전통 시장의 활기찬 분위기를 느끼며 다양한 길거리 음식을 즐길 수 있는 곳입니다. 밤에는 더욱 매력적인 장관을 제공합니다.
#
# 이 외에도 서울에는 많은 숨겨진 명소들이 있으니 서로의 취향에 맞게 다양한 장소들을 시도해 보세요.
# --------------------------------------------------

# %% [markdown]
# ## Async vs Sync

# %%
llm = ChatOpenAI(model="gpt-4o", api_key=api_key)
messages = [
    ("system", "당신은 서울의 음시과 문화 전문가 입니다."),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.")
]

# %%
import asyncio
import time

async def invoke_async(llm, messages):
    response = await llm.ainvoke(messages)
    print(response.content)

async def invoke_parallel(llm, messages):
    tasks = [invoke_async(llm, messages) for _ in range(10)]
    await asyncio.gather(*tasks)

# %%
print("Async")
start = time.perf_counter()
await invoke_parallel(llm, messages)
end = time.perf_counter()
print(f"Elapsed time: {end - start:.2f} seconds")
# Out:
# Async
# 서울에는 다양한 전통 음식을 맛볼 수 있는 훌륭한 레스토랑이 많이 있습니다. 여기 서울을 대표하는 음식을 맛볼 수 있는 5곳을 추천합니다:
#
# 1. **토속촌 삼계탕**: 경복궁 근처에 위치한 이곳은 삼계탕으로 유명합니다. 한방 재료와 함께 끓인 영양 가득한 국물과 부드러운 닭고기가 특징이며, 전통 한옥 분위기 속에서 식사를 즐길 수 있습니다.
#
# 2. **명동교자**: 명동에 위치한 이 식당은 서울 만두와 칼국수의 명소입니다. 진한 육수와 쫄깃한 면발의 칼국수, 그리고 고소한 맛의 만두가 맛있기로 유명합니다.
#
# 3. **깡스반점**: 익선동에 위치한 이곳은 한옥을 개조한 공간에서 비빔밥과 전통 한식 요리를 현대적으로 해석한 다양한 메뉴를 제공합니다. 전통과 현대가 조화롭게 어우러진 분위기 속에서 식사를 즐길 수 있습니다.
#
# 4. **전주비빔밥**: 광화문 근처에 있는 이 식당은 전주식 비빔밥을 전문으로 합니다. 다채로운 나물과 구운 고기, 고소한 참기름이 어우러진 전통 전주비빔밥을 맛볼 수 있습니다.
#
# 5. **마포 양꼬치**: 마포에 위치한 이곳은 양념장이 잘 배어 있는 양꼬치와 함께 다양한 중국식 볶음 요리를 제공합니다. 고소하고 쫄깃한 양꼬치는 서울의 중국 음식 중 꼭 한 번 맛볼 만한 메뉴입니다.
#
# 서울에서 전통적인 맛을 느끼고 싶다면 이곳들을 방문해 보세요. 각 레스토랑은 고유의 매력과 서울의 맛을 선사할 것입니다.
# 서울에서는 다양한 전통 음식을 맛볼 수 있는 훌륭한 레스토랑들이 많이 있습니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 다섯 곳의 추천 레스토랑입니다.
#
# 1. **광장시장** - 전통적인 한국 음식들을 다양하게 맛볼 수 있는 곳으로, 특히 빈대떡, 칼국수, 그리고 육회가 유명합니다. 광장시장은 서울의 오랜 시장 중 하나로 현지인들은 물론 관광객들에게도 인기 있는 장소입니다.
#
# 2. **산촌** - 인사동에 위치한 이곳은 전통 한정식을 제공하는 레스토랑으로, 산채 비빔밥과 같은 건강한 한식을 맛볼 수 있습니다. 고풍스러운 분위기 속에서 한국의 전통적인 메뉴를 즐길 수 있습니다.
#
# 3. **명동 교자** - 명동에 있는 이곳은 칼국수로 유명하며, 한국인들이 사랑하는 편안한 국수 요리를 경험할 수 있습니다. 매콤한 김치와 함께 제공되는 칼국수의 독특한 맛을 놓치지 마세요.
#
# 4. **정식당** - 미쉐린 가이드에 오른 고급 한식 레스토랑으로, 전통 한식을 현대적으로 재해석한 메뉴를 선보입니다. 화려한 프레젠테이션과 창의적인 요리로 유명한 곳입니다.
#
# 5. **우래옥** - 평양냉면 전문점으로, 한국 전통 냉면을 맛볼 수 있는 곳입니다. 서울에서 오랜 역사를 가진 평양냉면집으로, 시원하면서도 깊은 맛을 자랑합니다.
#
# 이 레스토랑들은 각각 고유한 매력을 지니고 있어, 서울의 다양한 음식 문화를 체험하기에 훌륭한 선택이 될 것입니다. 즐거운 식사 시간을 보내세요!
# 서울에서 대표적인 음식을 체험할 수 있는 레스토랑 몇 곳을 추천해 드리겠습니다. 이곳들은 전통적인 맛을 즐길 수 있는 유명한 장소들입니다.
#
# 1. **명동교자**
#    - **메뉴:** 칼국수
#    - **특징:** 명동에 위치한 이곳은 칼국수가 대표 메뉴이며, 진한 국물과 쫄깃한 면발이 일품입니다. 긴 대기줄이 있을 수 있지만 그만큼 맛을 보장하는 곳입니다.
#
# 2. **우래옥**
#    - **메뉴:** 평양냉면
#    - **특징:** 1946년부터 시작된 유서 깊은 레스토랑으로, 담백한 맛의 평양냉면이 유명합니다. 소고기 육수와 얇은 면발이 조화를 이루어 전통적인 맛을 제공합니다.
#
# 3. **한미리**
#    - **메뉴:** 한정식
#    - **특징:** 깔끔하고 정갈한 한정식을 맛볼 수 있는 곳으로, 다양한 반찬과 함께 전통적인 한국의 맛을 즐길 수 있는 곳입니다.
#
# 4. **강남면옥**
#    - **메뉴:** 비빔냉면
#    - **특징:** 비빔냉면과 함께 불고기를 즐길 수 있는 곳으로 소문난 곳입니다. 매콤달콤한 비빔냉면과 부드러운 불고기의 조화가 일품입니다.
#
# 5. **봉피양**
#    - **메뉴:** 갈비탕
#    - **특징:** 갈비탕으로 유명한 이곳에서는 깊고 진한 국물의 갈비탕을 즐길 수 있습니다. 소고기 육수로 끓여낸 국물은 깊은 맛을 자랑합니다.
#
# 이 레스토랑들은 서울의 대표적인 한국 음식을 맛볼 수 있는 곳들로, 각기 다른 매력을 지니고 있습니다. 예약이나 대기시간 등을 미리 확인하시고 방문하시는 것을 추천드립니다.
# 서울에는 다양한 전통 음식과 현대적인 변형을 맛볼 수 있는 훌륭한 레스토랑이 많습니다. 서울을 대표하는 음식을 맛보기에 좋은 곳 다섯 곳을 추천해드리겠습니다.
#
# 1. **한미리**: 전통 한식을 맛볼 수 있는 곳으로, 한정식이 특히 유명합니다. 계절에 맞는 재료로 담백한 맛을 살린 정갈한 요리를 선보이며, 전통적인 분위기 속에서 식사를 즐길 수 있습니다.
#
# 2. **순라네집**: 명동 근처에 위치한 순라네집은 한국 전통 고기요리인 갈비와 불고기가 훌륭한 곳입니다. 특히, 양념 갈비와 불고기 요리가 맛있으며, 관광객들과 현지인들에게 인기 있는 식당입니다.
#
# 3. **황생가 칼국수**: 이곳은 서울에서 가장 유명한 칼국수 집 중 하나로, 바지락을 듬뿍 넣어 시원하고 깔끔한 국물 맛이 일품입니다. 점심시간대에는 줄이 길지만, 금방 자리가 나니 기다릴 만한 가치가 있습니다.
#
# 4. **광장시장**: 경동시장 내에 위치한 광장시장은 전통 한식과 길거리 음식을 맛볼 수 있는 곳입니다. 특히 빈대떡, 육회, 마약김밥 등 다양한 길거리 음식과 전통 음식을 저렴하게 즐길 수 있어 현지인들에게도 인기가 높습니다.
#
# 5. **전주비빔밥 본점**: 비빔밥은 한국을 대표하는 음식 중 하나이며, 전주비빔밥 본점에서는 전통 방식으로 만들어진 비빔밥을 맛볼 수 있습니다. 신선한 재료와 고소한 참기름의 조화가 일품이며, 다양한 나물과 고명이 포함되어 있습니다.
#
# 이 레스토랑들은 서울에서 전통적인 한국 음식을 맛보고자 할 때 훌륭한 선택지가 될 것입니다.
# 서울에는 전통적인 한국 음식을 맛볼 수 있는 다양한 레스토랑이 많이 있습니다. 서울을 대표하는 음식을 맛볼 수 있는 몇 가지 추천 레스토랑은 다음과 같습니다.
#
# 1. **계림원 (Gyerimwon)**
#    - 위치: 종로구
#    - 추천 메뉴: 삼계탕
#    - 설명: 계림원은 서울에서 가장 오래된 삼계탕 전문점 중 하나로, 진한 육수와 부드러운 닭고기로 유명합니다.
#
# 2. **한국집 (Hangukjip)**
#    - 위치: 종로구
#    - 추천 메뉴: 비빔밥
#    - 설명: 정갈하고 다양한 재료로 만들어지는 전통 비빔밥을 맛볼 수 있는 곳으로, 한국의 전통적인 맛을 제대로 즐길 수 있습니다.
#
# 3. **서린낙지 (Seorin Nakji)**
#    - 위치: 중구
#    - 추천 메뉴: 낙지볶음
#    - 설명: 매콤하면서도 감칠맛 나는 낙지볶음으로 유명한 레스토랑입니다. 독특한 매운맛을 경험할 수 있습니다.
#
# 4. **토속촌 (Tosokchon)**
#    - 위치: 종로구
#    - 추천 메뉴: 삼계탕
#    - 설명: 한옥 스타일의 전통적인 한국 식당으로, 고소하고 깊은 맛의 삼계탕으로 많은 사람들에게 사랑받고 있습니다.
#
# 5. **유정식당 (Yujeong Sikdang)**
#    - 위치: 강남구
#    - 추천 메뉴: 갈비
#    - 설명: 양념된 갈비로 유명한 곳으로, 부드럽고 맛있는 고기를 맛볼 수 있는 레스토랑입니다.
#
# 이 레스토랑들은 전통적인 한국 음식을 경험하기에 좋은 선택지입니다. 각기 다른 지역의 분위기와 맛을 느껴보세요!
# 서울은 다양한 전통 음식과 현대적인 퓨전 요리를 모두 맛볼 수 있는 도시입니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳입니다:
#
# 1. **백년옥** - 순두부 전문점으로 유명한 백년옥은 깔끔하고 깊은 맛의 순두부찌개를 제공합니다. 특히, 전통 방식으로 만든 고소하고 부드러운 순두부가 인상적입니다. 위치는 서초구에 있습니다.
#
# 2. **명동교자** - 서울 명동에 위치한 이 식당은 깊은 감칠맛의 칼국수와 매콤한 비빔국수로 유명합니다. 고기 만두도 별미로 많은 사람들에게 사랑받고 있습니다.
#
# 3. **광장시장** - 전통 시장의 활기와 다양한 음식을 경험하고 싶다면 광장시장을 추천합니다. 빈대떡, 마약김밥, 떡볶이, 육회 등 서울의 길거리 음식을 맛볼 수 있는 완벽한 장소입니다.
#
# 4. **꽃, 밥에 피다** - 한식을 모던하게 재해석한 요리를 제공하는 이 레스토랑은 전통적인 한식에 현대적인 감각을 더했습니다. 특히, 다양한 전통 재료를 활용한 아름다운 플레이트 디자인이 돋보입니다.
#
# 5. **한미리** - 서울 시내 여러 곳에 위치한 한미리는 전통 한정식 코스를 경험할 수 있는 곳으로, 다양한 한식 요리를 정갈하게 즐길 수 있습니다. 신선한 계절 재료를 사용하여 건강한 한국식 메뉴를 제공합니다.
#
# 각 레스토랑은 저마다의 매력이 있으니, 서울에서의 미식 여행을 즐겨보세요!
# 서울은 다양한 전통과 현대적인 맛을 동시에 즐길 수 있는 멋진 도시입니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳을 추천드립니다.
#
# 1. **광장시장**: 전통 재래시장을 경험하고 싶다면 광장시장이 제격입니다. 여기서는 육회, 마약김밥, 빈대떡 등 다양한 한국 전통 음식을 길거리 스타일로 즐길 수 있습니다.
#
# 2. **한미리**: 한정식 전문 레스토랑인 한미리는 한국 전통 음식을 고급스럽게 즐길 수 있는 곳입니다. 정갈한 밑반찬과 함께 다양한 코스 요리가 제공됩니다.
#
# 3. **옥동식**: 돼지국밥으로 유명한 옥동식은 서울의 현대적인 감각을 가미한 국밥집입니다. 진하고 담백한 국물과 고기의 조화가 일품입니다.
#
# 4. **낙원떡볶이**: 매콤달콤한 떡볶이의 진수를 경험하고 싶다면 낙원떡볶이를 추천합니다. 오랜 역사를 자랑하며, 고구마튀김과 순대 등 다양한 사이드 메뉴도 함께 즐길 수 있습니다.
#
# 5. **화동옥**: 불고기와 전통 곰탕을 전문으로 하는 화동옥은 깊은 맛을 자랑하는 서울 스타일의 고급 한식 레스토랑입니다. 질 좋은 한우로 만든 불고기를 맛볼 수 있습니다.
#
# 이 레스토랑들에서 서울의 대표적인 맛과 정서를 경험해 보시기 바랍니다.
# 서울은 다양한 전통 음식과 현대적인 해석이 어우러진 맛집들이 많이 있습니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해 드리겠습니다.
#
# 1. **한정식 - 궁연**: 전통적인 한정식을 맛볼 수 있는 곳으로, 정갈하게 차려진 밥상과 함께 한국의 다양한 반찬과 찌개를 경험할 수 있습니다. 궁과 같은 분위기에서 식사할 수 있는 점이 매력적입니다.
#
# 2. **비빔밥 - 전주비빔밥**: 서울 곳곳에 있는 여러 전주비빔밥 전문점을 찾아가 보세요. 특히 비빔밥은 여러 가지 나물과 고추장이 조화를 이루며, 지역에 따라 약간씩 다른 맛을 경험할 수 있습니다.
#
# 3. **설렁탕 - 신의주 설렁탕**: 수십 년 역사를 자랑하는 설렁탕 전문점입니다. 깊고 진한 국물과 부드러운 고기가 특징이며, 오랫동안 현지인들께 사랑받아온 곳입니다.
#
# 4. **불고기 - 사리원 불고기**: 한국식 바비큐의 고전인 불고기를 맛볼 수 있는 명소입니다. 양념된 고기를 직접 구워 먹는 방식으로 한국의 먹거리 문화를 체험할 수 있습니다.
#
# 5. **김치찌개 - 청진식당**: 진짜 한국의 맛을 경험하고 싶다면 김치찌개 전문점이 제격입니다. 청진식당은 김치의 깊은 맛과 부드러운 돼지고기 조각이 잘 어우러져 현지인이 자주 찾는 인기 맛집입니다.
#
# 이 외에도 서울 곳곳에는 다양한 한식 레스토랑이 많으니, 서울의 음식 문화를 다양하게 경험해 보시기 바랍니다.
# 서울의 음식을 대표하는 여러 레스토랑이 있지만, 다음은 특히 추천할 만한 다섯 곳입니다:
#
# 1. **광장시장** - 광장시장은 전통적인 한국 시장의 분위기를 느낄 수 있는 곳으로, 빈대떡, 육회, 김밥 등 다양한 한국 음식을 맛볼 수 있는 곳입니다. 시장 내 각종 작은 식당에서 진정한 한국 길거리 음식을 경험해 보세요.
#
# 2. **백반집** - 백반은 한국 가정식을 대표하는 메뉴로, 서울에는 품질 좋은 백반을 제공하는 곳이 많습니다. 그 중에서도 종로구에 위치한 '토속촌'은 다양한 반찬과 함께 제공되는 삼계탕으로 유명합니다.
#
# 3. **조선호텔 아리아** - 조선호텔의 뷔페 레스토랑 아리아는 고급스러운 분위기 속에서 다양한 한식을 포함한 여러 국제 음식을 즐길 수 있는 곳입니다. 특히 한식 코너에서는 전통적인 요리를 현대적으로 재해석한 메뉴를 제공합니다.
#
# 4. **명동교자** - 명동에 위치한 이곳은 칼국수로 유명하며, 서울을 여행하는 많은 사람들에게 사랑받는 곳입니다. 따뜻하고 깊은 맛을 자랑하는 육수와 쫄깃한 면발을 가진 칼국수는 한끼 든든한 식사로 손색이 없습니다.
#
# 5. **한미리** - 청담동에 위치한 한미리는 고급 한정식을 제공하는 레스토랑으로, 정갈한 반찬과 조화로운 한정식을 맛볼 수 있는 곳입니다. 전통적인 상차림과 현대적인 프레젠테이션이 결합되어 특별한 식사를 경험할 수 있습니다.
#
# 이 외에도 서울에는 다양한 한식을 맛볼 수 있는 레스토랑이 많이 있으니, 취향에 맞는 다양한 곳을 탐방해보시길 권장합니다.
# 서울에는 다양한 전통 한식과 현대적인 변화를 겪은 퓨전 요리를 맛볼 수 있는 레스토랑이 많이 있습니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳을 추천합니다.
#
# 1. **광장시장**:
#    - 음식: 빈대떡, 마약김밥, 육회
#    - 설명: 광장시장은 다양한 전통 한국 음식을 길거리 스타일로 즐길 수 있는 곳입니다. 다양한 한식 음식을 맛볼 수 있는 경험을 제공합니다.
#
# 2. **농민백암순대**:
#    - 음식: 순댓국
#    - 설명: 탁월한 순댓국으로 유명한 이곳은 현지인들에게 오랫동안 사랑받아온 맛집입니다. 깊고 진한 국물 맛이 일품입니다.
#
# 3. **우래옥**:
#    - 음식: 냉면, 불고기
#    - 설명: 우래옥은 전통 평양냉면과 고급 불고기로 유명한 곳입니다. 무려 몇 세대에 걸친 전통의 맛을 계승하고 있습니다.
#
# 4. **한일관**:
#    - 음식: 육개장, 갈비구이
#    - 설명: 전통적인 한국의 갈비구이와 탕을 전문으로 하는 유명한 한식 레스토랑입니다. 풍부한 맛과 쾌적한 분위기를 자랑합니다.
#
# 5. **이차돌**:
#    - 음식: 한우 바비큐, 차돌박이
#    - 설명: 고품질 한우와 차돌박이를 제공하는 바비큐 전문점으로, 고기 품질과 다양한 곁들이 메뉴가 인기입니다.
#
# 이 레스토랑들은 각각 고유한 맛과 전통을 자랑하며, 서울의 다양한 먹거리를 즐길 수 있는 좋은 장소입니다. 방문하기 전에 예약하거나 운영 시간을 확인하는 것을 추천드립니다.
# Elapsed time: 12.05 seconds

# %%
print("Sync")
start = time.perf_counter()
for i in range(10):
    response = llm.invoke(messages)
    print(response.content)
    print()
end = time.perf_counter()
print(f"Elapsed time: {end - start:.2f} seconds")
# Out:
# Sync
# 서울을 대표하는 음식을 맛볼 수 있는 레스토랑은 다양하지만, 전통적인 맛과 현대적인 해석을 잘 조화시킨 몇 곳을 추천해드릴게요.
#
# 1. **용수산** - 한식당 중에서도 정통성을 잘 살린 곳으로 유명하며, 특히 전통 한정식을 경험하기에 적합합니다. 계절에 따라 다른 재료로 구성하는 한정식 코스가 인기입니다.
#
# 2. **맷돌순두부** - 서울에서 순두부를 맛볼 수 있는 대표적인 곳 중 하나입니다. 특히 매장에서 직접 만드는 고소한 순두부와 다양한 한식 반찬이 잘 어울립니다.
#
# 3. **북촌 손만두** - 전통적인 방식으로 만든 손만두를 맛볼 수 있는 곳입니다. 만둣국과 함께 곁들여지는 다양한 반찬들이 매력적입니다. 북촌 한옥마을과 가까워 식사 후 산책하기에도 좋습니다.
#
# 4. **산정** - 삼계탕을 맛볼 수 있는 곳으로, 삼계탕은 여름철 특히 인기가 많습니다. 전통적인 방식을 고수하면서도 현대인에게 맞춰 조리한 삼계탕은 건강식으로도 좋습니다.
#
# 5. **산들해** - 모던한 분위기 속에서 젓갈이나 장아찌 같은 전통 한식을 기반으로 한 창작 요리를 맛볼 수 있습니다. 전통과 현대의 조화를 추구하는 요리들이 인상적입니다.
#
# 이들 레스토랑은 서울의 전통적인 맛뿐만 아니라 현대적인 감각을 더한 요리들로 그 지역의 미식 문화를 경험하기에 좋은 선택입니다.
#
# 서울에는 다양한 전통과 현대적인 음식을 즐길 수 있는 레스토랑이 많이 있습니다. 서울을 대표하는 음식을 맛볼 수 있는 몇 가지 추천 레스토랑은 다음과 같습니다.
#
# 1. **한국관 (Korea House)**:
#    - 위치: 중구 필동
#    - 특징: 전통 한정식을 맛볼 수 있는 곳으로, 특히 외국인 방문객들에게 인기가 많습니다. 한국 전통 공연도 함께 즐길 수 있어 특별한 경험을 제공합니다.
#
# 2. **명동교자 (Myeongdong Kyoja)**:
#    - 위치: 중구 명동
#    - 특징: 칼국수와 만두가 유명한 곳입니다. 오랜 역사를 자랑하며, 부드럽고 든든한 국물과 쫄깃한 면이 일품입니다.
#
# 3. **광장시장 (Gwangjang Market)**:
#    - 위치: 종로구 예지동
#    - 특징: 다양한 길거리 음식을 맛볼 수 있는 전통 시장입니다. 빈대떡, 마약김밥, 순대 등 서울의 대표적인 전통 먹거리가 가득합니다.
#
# 4. **백년옥 (Baeknyeonok)**:
#    - 위치: 서초구 방배동
#    - 특징: 순두부 요리로 유명한 곳입니다. 담백하고 부드러운 순두부와 다양한 반찬을 함께 즐길 수 있습니다.
#
# 5. **소고 (Soogo)**:
#    - 위치: 강남구 신사동
#    - 특징: 현대적인 감각을 더한 한국 전통 요리를 맛볼 수 있습니다. 세심하게 준비된 메뉴와 깔끔한 인테리어가 어우러져 특별한 식사를 제공합니다.
#
# 이 레스토랑들은 서울에서 다양한 한국 요리를 경험하기에 좋은 선택지입니다. 방문할 때 예약을 하는 것이 좋으며, 운영 시간과 메뉴를 미리 확인하는 것을 추천드립니다.
#
# 서울에서 서울을 대표하는 음식을 맛볼 수 있는 레스토랑은 다양하게 존재합니다. 다음은 서울의 전통적이고 대표적인 음식을 경험할 수 있는 다섯 개의 레스토랑입니다:
#
# 1. **명동교자(Myeongdong Kyoja)**: 명동에 위치한 이곳은 소문난 칼국수 집으로, 40년 넘게 같은 맛을 유지하고 있습니다. 칼국수와 함께 나오는 만두도 맛이 일품입니다.
#
# 2. **세븐데이즈서울(Seven Days Seoul)**: 광화문 근처에 위치한 이 레스토랑은 비빔밥과 불고기로 유명합니다. 전통적인 방식으로 요리된 비빔밥은 현지인과 관광객 모두에게 인기가 높습니다.
#
# 3. **한복남(Hanboknam)**: 전주비빔밥을 제대로 맛볼 수 있는 곳으로, 전통적인 반상 스타일로 다양한 반찬과 함께 제공됩니다.
#
# 4. **신선설농탕(Sinseon Seolnongtang)**: 설렁탕 전문점으로, 깊고 진한 국물 맛이 일품입니다. 오랜 시간 동안 우러난 국물은 한국의 전통적인 맛을 제대로 느낄 수 있게 해줍니다.
#
# 5. **토속촌 삼계탕(Tosokchon Samgyetang)**: 경복궁 근처에 위치한 삼계탕 전문점으로, 전통 한옥 분위기에서 한국의 대표적인 보양 음식을 경험할 수 있습니다.
#
# 이 레스토랑들은 전통적인 한국 음식을 맛보기에 좋은 곳으로, 서울의 미식 문화를 제대로 경험할 수 있을 것입니다.
#
# 서울에는 다양한 한식 요리를 맛볼 수 있는 훌륭한 레스토랑이 많이 있습니다. 여기 서울을 대표하는 음식을 경험할 수 있는 다섯 곳을 추천드립니다.
#
# 1. **한국집**: 전주 비빔밥의 오리지널 맛을 서울에서 경험하고 싶다면 광화문 근처의 한국집을 방문해 보세요. 전통적인 방식으로 정성껏 준비된 비빔밥과 함께 다양한 반찬을 즐길 수 있습니다.
#
# 2. **오묘한정식**: 한식의 정수를 경험할 수 있는 곳으로, 계절에 맞춰 준비된 고품질의 재료로 만든 한정식을 맛볼 수 있습니다. 다양한 반찬과 메인 요리가 조화를 이루는 곳입니다.
#
# 3. **마포원조 돼지갈비**: 서울에서 돼지갈비를 맛보고 싶다면 마포에 위치한 이곳을 추천합니다. 숯불에 구워진 돼지갈비의 풍미와 함께 김치찌개 등 다양한 반찬이 일품입니다.
#
# 4. **계열사신당동**: 서울의 길거리 음식 문화를 대표하는 떡볶이를 맛볼 수 있는 곳입니다. 매콤달콤한 떡볶이뿐만 아니라 튀김, 순대 등 다양한 간식을 함께 즐길 수 있습니다.
#
# 5. **진진**: 서울에서 한국식 중식을 경험하고 싶다면 마포구에 위치한 진진을 방문해 보세요. 짬뽕, 짜장면 등의 인기 메뉴와 더불어 탕수육이 특히 유명합니다.
#
# 이 레스토랑들은 전통적인 서울의 맛을 경험할 수 있는 곳으로, 각기 다른 매력을 지니고 있습니다. 방문 전에 운영 시간과 예약 가능 여부를 확인하는 것이 좋습니다.
#
# 서울은 다양한 전통과 현대적인 음식을 제공하는 맛의 천국입니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 다섯 곳을 소개해드리겠습니다:
#
# 1. **목포집** - 이 레스토랑은 갈비찜으로 유명합니다. 부드럽게 조리된 갈비와 풍부한 양념의 조화가 일품입니다. 종로구에 위치하여 관광객들에게도 접근성이 좋습니다.
#
# 2. **암소서울** - 한우를 전문으로 하는 고급 레스토랑으로, 특히 한우구이와 육회가 뛰어납니다. 강남구에 위치해 있으며, 고급스러운 분위기에서 정통 한우 요리를 즐길 수 있습니다.
#
# 3. **조선호떡** - 종로에 위치한 작은 노점으로, 전통 호떡을 맛볼 수 있는 곳입니다. 달콤한 설탕과 견과류가 들어간 호떡은 한국 길거리 음식의 매력을 느끼게 합니다.
#
# 4. **갓덴스시** - 서울에서 수준 높은 스시를 맛볼 수 있는 곳 중 하나입니다. 신선한 재료와 정교한 손맛이 돋보이는 이곳은 전통 일식과 현대적인 해석이 어우러져 있습니다. 강남구에 위치해 있습니다.
#
# 5. **명동교자** - 명동에 위치한 이곳은 칼국수로 매우 유명합니다. 진한 육수와 쫄깃한 면발, 그리고 썰어낸 만두까지 한 그릇에 담겨 인기 있는 곳입니다.
#
# 이 레스토랑들은 서울에서 꼭 한번 맛볼 만한 음식들을 제공합니다. 방문하셔서 서울의 다채로운 맛을 경험해보세요.
#
# 서울은 다양한 전통 음식을 경험할 수 있는 곳이지만, 특히 아래의 레스토랑들은 서울을 대표하는 음식을 맛볼 수 있는 장소로 잘 알려져 있습니다.
#
# 1. **광장시장**:
#    - *특징*: 비록 개별적인 레스토랑은 아니지만, 광장시장은 다양한 전통 한국 음식을 맛볼 수 있는 명소입니다. 마약김밥, 빈대떡, 떡볶이, 순대 등 다양한 스트리트 푸드를 즐길 수 있습니다.
#
# 2. **한우마을 정육식당 (마포)**:
#    - *특징*: 한우 구이로 유명합니다. 한국의 대표적인 고기 요리를 맛볼 수 있으며, 고기의 품질과 맛을 제대로 경험할 수 있습니다.
#
# 3. **고려삼계탕 (종로구)**:
#    - *특징*: 삼계탕은 한국의 전통적인 보양식 중 하나입니다. 고려삼계탕은 오랜 전통을 가지고 있으며, 향토적인 맛을 자랑합니다.
#
# 4. **명동교자 (명동)**:
#    - *특징*: 명동교자는 손칼국수와 만두로 유명합니다. 부드럽고 쫄깃한 면발과 고소한 육수의 조화가 일품입니다.
#
# 5. **토속촌 (종로구)**:
#    - *특징*: 또 다른 삼계탕 맛집으로, 특히 인삼과 같은 한약재가 들어가 깊은 맛을 냅니다. 외국인 관광객들에게도 인기가 많습니다.
#
# 이 레스토랑들은 서울을 방문하는 사람들에게 전통 한국 요리의 진수를 경험할 수 있는 기회를 제공합니다. 각기 다른 특징과 맛을 느낄 수 있어 서울의 다채로운 음식을 탐험하기에 좋습니다.
#
# 서울에는 다양한 전통음식을 맛볼 수 있는 레스토랑이 많습니다. 서울을 대표하는 음식을 경험하기 좋은 다섯 곳을 추천해드립니다.
#
# 1. **한국집 (Gwangjang Market)**:
#    - 광장시장에 위치한 한국집은 전통적인 한국 음식을 맛볼 수 있는 역사적인 장소입니다. 특히 비빔밥과 육회, 김밥 등을 즐길 수 있습니다. 시장 특유의 활기찬 분위기 속에서 현지인과 관광객 모두에게 인기가 많습니다.
#
# 2. **명동교자 (Myeongdong Kyoja)**:
#    - 명동에 위치한 이 레스토랑은 칼국수로 유명하며, 서울의 클래식한 명소 중 하나입니다. 부드러운 면과 깊은 국물, 만두가 특징이며 간편하면서도 만족스러운 식사를 제공합니다.
#
# 3. **한미리**:
#    - 전통 한정을 맛볼 수 있는 곳으로, 종로구에 위치해 있습니다. 다양한 반찬과 함께 제공되는 한정식은 한국의 정통적인 식문화를 체험할 수 있는 좋은 기회를 제공합니다.
#
# 4. **옥동식**:
#    - 홍대 입구 근처에 위치한 옥동식은 돼지곰탕을 전문으로 하는 곳입니다. 담백하고 깊은 맛의 국물은 많은 사람들에게 사랑받고 있으며, 한국의 전통적인 국밥 문화를 경험할 수 있습니다.
#
# 5. **풍년집**:
#    - 종로에 위치한 풍년집은 전통적인 막걸리와 함께 부침개, 전 등을 즐길 수 있는 곳입니다. 아늑한 분위기에서 전통적인 한국 술과 안주를 즐기기에 좋습니다.
#
# 이 레스토랑들은 서울의 다양한 음식을 경험할 수 있는 곳으로, 전통적이면서도 현대적인 서울의 맛을 모두 경험하실 수 있습니다.
#
# 서울에서 전통적이고도 현대적인 매력을 지닌 대표 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해드리겠습니다.
#
# 1. **한국집 (Korea House)**:
#    전통 한정식 코스를 경험하고 싶다면 한국집을 추천합니다. 한국의 다양한 전통 음식을 고급스럽게 즐길 수 있는 곳으로, 특히 고급 재료를 사용한 궁중 한식을 맛볼 수 있습니다.
#
# 2. **놀부부대찌개 (Nolboo Budaejjigae)**:
#    한국의 퓨전 전골 요리인 부대찌개를 맛볼 수 있는 대표적인 체인점입니다. 다양한 재료가 풍부하게 들어가 있어 한국식 라면과 함께 매콤하게 즐길 수 있습니다.
#
# 3. **산촌 (Sanchon)**:
#    인사동에 위치한 산촌은 채식주의자에게도 적합한 사찰 음식 전문점입니다. 자연산 재료를 기본으로 한 건강하고 정갈한 한식을 경험할 수 있습니다.
#
# 4. **토속촌 (Tosokchon)**:
#    경복궁 근처에 위치한 토속촌은 서울에서 가장 유명한 삼계탕 맛집 중 하나입니다. 진하고 깊은 맛의 한방 삼계탕으로 몸보신을 할 수 있습니다.
#
# 5. **옥루몽 (O’ngo Food Communications)**:
#    서울 광장시장에 위치한 이곳은 다양한 한국 전통 음식 투어를 제공합니다. 김치, 전, 떡볶이 같은 서울 대표 음식을 다양하게 접할 수 있는 경험을 제공하며, 직접 만들어보는 쿠킹 클래스도 참여할 수 있습니다.
#
# 서울은 이 외에도 다양한 한식 레스토랑이 많으니, 각자의 맛과 취향에 맞는 장소를 찾아보는 것도 재미있을 것입니다.
#
# 서울은 다양한 음식 문화가 공존하는 도시로, 전통 한식부터 현대적인 퓨전 요리까지 즐길 수 있는 레스토랑이 많습니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳을 추천해드리겠습니다.
#
# 1. **깡장집 (Kangjangjib)**
#    - 위치: 종로구
#    - 대표 메뉴: 비빔밥, 불고기
#    - 특징: 한옥 스타일의 전통적인 분위기에서 다양한 전통 한식을 맛볼 수 있는 곳입니다.
#
# 2. **미쉘린 가이드 서울 – 밍글스 (Mingles)**
#    - 위치: 강남구
#    - 대표 메뉴: 모던 한식 코스 요리
#    - 특징: 한식의 정수를 현대적으로 재해석하여 미쉘린 별을 받은 고급 레스토랑입니다.
#
# 3. **명동교자**
#    - 위치: 중구
#    - 대표 메뉴: 칼국수, 만두
#    - 특징: 담백하고 깊은 맛의 칼국수와 고소한 육즙이 가득한 만두로 유명한 곳입니다.
#
# 4. **유즈라멘**
#    - 위치: 마포구
#    - 대표 메뉴: 라멘, 짬뽕
#    - 특징: 서울에 위치한 일본식 라멘 전문점으로, 서울 사람들에게도 많은 사랑을 받고 있습니다. 짬뽕 맛의 라멘은 한국적인 느낌을 더해줍니다.
#
# 5. **새벽집**
#    - 위치: 강남구
#    - 대표 메뉴: 육회비빔밥, 갈비탕
#    - 특징: 24시간 운영되어 언제든지 한국 전통 육회와 갈비탕을 맛볼 수 있는 곳입니다.
#
# 이 레스토랑들은 서울의 다양한 음식 문화를 잘 보여주며, 전통적인 맛과 현대적인 해석을 모두 즐길 수 있습니다. 방문 전에 예약을 추천드립니다.
#
# 서울은 다양한 전통과 현대 요리를 경험할 수 있는 훌륭한 식당들이 많습니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 다섯 개의 추천 레스토랑입니다:
#
# 1. **진진반상** - 이곳은 전통 한식을 현대적으로 재해석하여 제공하는 곳으로, 깔끔하고 정갈한 반찬과 함께 다양한 밥상 메뉴를 즐길 수 있습니다. 특히 비빔밥과 갈비찜이 인기 있습니다.
#
# 2. **곰탕집 현대옥** - 현대옥은 전통적인 곰탕을 맛볼 수 있는 곳으로, 깊고 진한 국물과 부드러운 소고기가 일품입니다. 한국의 전통적이고 소박한 맛을 경험하고자 할 때 방문하기 좋습니다.
#
# 3. **북막골 한정식** - 이곳은 정갈한 한정식을 제공하며, 다양한 반찬과 고품질의 메인 요리들을 경험할 수 있습니다. 아름다운 인테리어 속에서 전통 한식을 맛볼 수 있는 좋은 기회입니다.
#
# 4. **삼청동 수연산방** - 전통 차와 다과를 즐기며 고즈넉한 분위기를 경험할 수 있는 한식 디저트 카페입니다. 조용한 한옥에서 전통 차와 함께 한국의 디저트를 맛보고 싶다면 추천합니다.
#
# 5. **명동교자** - 명동교자는 칼국수와 만두로 유명한 곳으로, 오래전부터 사랑받아온 강한 육수 맛이 특징입니다. 빠르고 편안하게 한식을 맛볼 수 있어 많은 관광객들에게 인기입니다.
#
# 이러한 레스토랑들은 서울의 다양한 한식 문화를 경험할 수 있는 기회를 제공합니다. 맛있는 음식을 통해 한국의 전통과 현대의 맛을 모두 느껴보시길 바랍니다.
#
# Elapsed time: 71.49 seconds

# %% [markdown]
# # 대화 히스토리 저정하기

# %% [markdown]
# ## messages에 추가해서 해결하기

# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage(content="당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다."), 
    HumanMessage(content="부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.")
]

response = llm.invoke(messages)

# %%
# 받은 응답을 messages에 추가하고, messages
messages.append(response)

# %%
messages
# Out:
# [SystemMessage(content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='부산에서 딱 한 곳만 가야 한다면 해운대를 추천합니다. 해운대는 부산을 대표하는 아름다운 해변으로, 넓고 깨끗한 백사장과 푸른 바닷물이 어우러져 매력적인 경치를 제공합니다. 해운대 주변에는 다양한 레스토랑과 카페가 있어 식사를 즐기기에도 좋고, 바다를 보며 산책하기에도 훌륭한 장소입니다. 또한, 해운대 바다의 일출은 놓치기 아쉬운 장관 중 하나입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 123, 'prompt_tokens': 49, 'total_tokens': 172, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BfhzuWG4b0VRpesRs7kmyajLYfMo2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--3ad61a0f-5182-43f7-9e28-81aafe97279b-0', usage_metadata={'input_tokens': 49, 'output_tokens': 123, 'total_tokens': 172, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
# messages의 제일 마지막 요소 삭제
# del messages[-1]

# %%
# messages
for message in messages:
    print(type(message), message.content)
    # print(message.content)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> 당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.
# <class 'langchain_core.messages.human.HumanMessage'> 부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.
# <class 'langchain_core.messages.ai.AIMessage'> 부산에서 딱 한 곳만 가야 한다면 해운대를 추천합니다. 해운대는 부산을 대표하는 아름다운 해변으로, 넓고 깨끗한 백사장과 푸른 바닷물이 어우러져 매력적인 경치를 제공합니다. 해운대 주변에는 다양한 레스토랑과 카페가 있어 식사를 즐기기에도 좋고, 바다를 보며 산책하기에도 훌륭한 장소입니다. 또한, 해운대 바다의 일출은 놓치기 아쉬운 장관 중 하나입니다.

# %% [markdown]
# - 두번째 질문과 messages에 추가하기

# %%
messages.append(HumanMessage(content="부산역에서 그곳에 가는 교통편을 알려주세요."))
messages
# Out:
# [SystemMessage(content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='부산에서 딱 한 곳만 가야 한다면 해운대를 추천합니다. 해운대는 부산을 대표하는 아름다운 해변으로, 넓고 깨끗한 백사장과 푸른 바닷물이 어우러져 매력적인 경치를 제공합니다. 해운대 주변에는 다양한 레스토랑과 카페가 있어 식사를 즐기기에도 좋고, 바다를 보며 산책하기에도 훌륭한 장소입니다. 또한, 해운대 바다의 일출은 놓치기 아쉬운 장관 중 하나입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 123, 'prompt_tokens': 49, 'total_tokens': 172, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BfhzuWG4b0VRpesRs7kmyajLYfMo2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--3ad61a0f-5182-43f7-9e28-81aafe97279b-0', usage_metadata={'input_tokens': 49, 'output_tokens': 123, 'total_tokens': 172, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='부산역에서 그곳에 가는 교통편을 알려주세요.', additional_kwargs={}, response_metadata={})]

# %%
# messages로 llm에 요청
response = llm.invoke(messages)

# 두번째 질문에 대한 응답을 messages에 추가
messages.append(response)

# messages 결과 확인
for message in messages:
    print(type(message), message)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산에서 딱 한 곳만 가야 한다면 해운대를 추천합니다. 해운대는 부산을 대표하는 아름다운 해변으로, 넓고 깨끗한 백사장과 푸른 바닷물이 어우러져 매력적인 경치를 제공합니다. 해운대 주변에는 다양한 레스토랑과 카페가 있어 식사를 즐기기에도 좋고, 바다를 보며 산책하기에도 훌륭한 장소입니다. 또한, 해운대 바다의 일출은 놓치기 아쉬운 장관 중 하나입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 123, 'prompt_tokens': 49, 'total_tokens': 172, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BfhzuWG4b0VRpesRs7kmyajLYfMo2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--3ad61a0f-5182-43f7-9e28-81aafe97279b-0' usage_metadata={'input_tokens': 49, 'output_tokens': 123, 'total_tokens': 172, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산역에서 해운대 해변으로 가는 가장 일반적인 방법은 지하철을 이용하는 것입니다. 다음은 지하철을 이용한 경로입니다.\n\n1. **부산역 지하철**: 부산역에서 부산 지하철 1호선을 타고 서면역으로 이동합니다.\n   \n2. **환승**: 서면역에서 2호선으로 환승합니다.\n\n3. **해운대역**: 2호선을 타고 해운대역까지 이동합니다. 해운대역은 부산 지하철 2호선에 위치해 있습니다.\n\n4. **도보 이동**: 해운대역에서 하차한 후, 해운대 해변까지는 도보로 약 10~15분 정도 걸립니다. 역에서 해운대 해변 방향으로 가는 표지판을 따라 걸어가시면 쉽게 도착할 수 있습니다.\n\n지하철을 이용하면 대략 1시간 정도 소요됩니다. 부산의 교통 상황에 따라 이동 시간이 변동될 수 있으니 참고하시기 바랍니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 231, 'prompt_tokens': 196, 'total_tokens': 427, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-Bfi1pN035uy1WrunldKPn02kkPkYT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--fd841799-2a52-4f13-9929-2c9571dd7963-0' usage_metadata={'input_tokens': 196, 'output_tokens': 231, 'total_tokens': 427, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
for message in messages:
    print(message)
# Out:
# content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# content='부산에서 딱 한 곳만 가야 한다면 해운대를 추천합니다. 해운대는 부산을 대표하는 아름다운 해변으로, 넓고 깨끗한 백사장과 푸른 바닷물이 어우러져 매력적인 경치를 제공합니다. 해운대 주변에는 다양한 레스토랑과 카페가 있어 식사를 즐기기에도 좋고, 바다를 보며 산책하기에도 훌륭한 장소입니다. 또한, 해운대 바다의 일출은 놓치기 아쉬운 장관 중 하나입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 123, 'prompt_tokens': 49, 'total_tokens': 172, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BfhzuWG4b0VRpesRs7kmyajLYfMo2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--3ad61a0f-5182-43f7-9e28-81aafe97279b-0' usage_metadata={'input_tokens': 49, 'output_tokens': 123, 'total_tokens': 172, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# content='부산역에서 해운대 해변으로 가는 가장 일반적인 방법은 지하철을 이용하는 것입니다. 다음은 지하철을 이용한 경로입니다.\n\n1. **부산역 지하철**: 부산역에서 부산 지하철 1호선을 타고 서면역으로 이동합니다.\n   \n2. **환승**: 서면역에서 2호선으로 환승합니다.\n\n3. **해운대역**: 2호선을 타고 해운대역까지 이동합니다. 해운대역은 부산 지하철 2호선에 위치해 있습니다.\n\n4. **도보 이동**: 해운대역에서 하차한 후, 해운대 해변까지는 도보로 약 10~15분 정도 걸립니다. 역에서 해운대 해변 방향으로 가는 표지판을 따라 걸어가시면 쉽게 도착할 수 있습니다.\n\n지하철을 이용하면 대략 1시간 정도 소요됩니다. 부산의 교통 상황에 따라 이동 시간이 변동될 수 있으니 참고하시기 바랍니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 231, 'prompt_tokens': 196, 'total_tokens': 427, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-Bfi1pN035uy1WrunldKPn02kkPkYT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--fd841799-2a52-4f13-9929-2c9571dd7963-0' usage_metadata={'input_tokens': 196, 'output_tokens': 231, 'total_tokens': 427, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# - 마지막 메시지 참조

# %%
# 마지막 질문에 대한 응답 결과를 messages에서 확인하기

print(messages[-1].content)
# Out:
# 부산역에서 해운대 해변으로 가는 가장 일반적인 방법은 지하철을 이용하는 것입니다. 다음은 지하철을 이용한 경로입니다.
#
# 1. **부산역 지하철**: 부산역에서 부산 지하철 1호선을 타고 서면역으로 이동합니다.
#
# 2. **환승**: 서면역에서 2호선으로 환승합니다.
#
# 3. **해운대역**: 2호선을 타고 해운대역까지 이동합니다. 해운대역은 부산 지하철 2호선에 위치해 있습니다.
#
# 4. **도보 이동**: 해운대역에서 하차한 후, 해운대 해변까지는 도보로 약 10~15분 정도 걸립니다. 역에서 해운대 해변 방향으로 가는 표지판을 따라 걸어가시면 쉽게 도착할 수 있습니다.
#
# 지하철을 이용하면 대략 1시간 정도 소요됩니다. 부산의 교통 상황에 따라 이동 시간이 변동될 수 있으니 참고하시기 바랍니다.

# %% [markdown]
# - 사용자 메시지 추가하고, 질문, 응답

# %%
messages.append(HumanMessage(content="그 근처에 먹을 만한 음식점들을 추천해주세요."))
response = llm.invoke(messages)
messages.append(response)
for message in messages:
    print(type(message), message)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산에서 딱 한 곳만 가야 한다면 해운대를 추천합니다. 해운대는 부산을 대표하는 아름다운 해변으로, 넓고 깨끗한 백사장과 푸른 바닷물이 어우러져 매력적인 경치를 제공합니다. 해운대 주변에는 다양한 레스토랑과 카페가 있어 식사를 즐기기에도 좋고, 바다를 보며 산책하기에도 훌륭한 장소입니다. 또한, 해운대 바다의 일출은 놓치기 아쉬운 장관 중 하나입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 123, 'prompt_tokens': 49, 'total_tokens': 172, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BfhzuWG4b0VRpesRs7kmyajLYfMo2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--3ad61a0f-5182-43f7-9e28-81aafe97279b-0' usage_metadata={'input_tokens': 49, 'output_tokens': 123, 'total_tokens': 172, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산역에서 해운대 해변으로 가는 가장 일반적인 방법은 지하철을 이용하는 것입니다. 다음은 지하철을 이용한 경로입니다.\n\n1. **부산역 지하철**: 부산역에서 부산 지하철 1호선을 타고 서면역으로 이동합니다.\n   \n2. **환승**: 서면역에서 2호선으로 환승합니다.\n\n3. **해운대역**: 2호선을 타고 해운대역까지 이동합니다. 해운대역은 부산 지하철 2호선에 위치해 있습니다.\n\n4. **도보 이동**: 해운대역에서 하차한 후, 해운대 해변까지는 도보로 약 10~15분 정도 걸립니다. 역에서 해운대 해변 방향으로 가는 표지판을 따라 걸어가시면 쉽게 도착할 수 있습니다.\n\n지하철을 이용하면 대략 1시간 정도 소요됩니다. 부산의 교통 상황에 따라 이동 시간이 변동될 수 있으니 참고하시기 바랍니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 231, 'prompt_tokens': 196, 'total_tokens': 427, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-Bfi1pN035uy1WrunldKPn02kkPkYT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--fd841799-2a52-4f13-9929-2c9571dd7963-0' usage_metadata={'input_tokens': 196, 'output_tokens': 231, 'total_tokens': 427, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# <class 'langchain_core.messages.human.HumanMessage'> content='그 근처에 먹을 만한 음식점들을 추천해주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='해운대 근처에는 다양한 음식점들이 있어 선택의 폭이 넓습니다. 다음은 몇 가지 추천하고 싶은 음식점들입니다.\n\n1. **밀양돼지국밥**: 부산의 유명한 지역 음식인 돼지국밥을 맛볼 수 있는 곳입니다. 깔끔한 국물과 푸짐한 고기 양으로 인기가 많습니다.\n\n2. **해운대 암소갈비**: 해운대에서는 소갈비도 좋은 선택입니다. 질 좋은 고기를 합리적인 가격에 맛볼 수 있어 방문객들에게 인기가 많습니다.\n\n3. **동백섬 해녀촌**: 싱싱한 해산물을 원한다면 이곳을 추천드립니다. 해녀들이 직접 잡은 해산물로 만든 회와 해물탕을 즐길 수 있습니다.\n\n4. **마키야**: 일본식 라멘을 맛볼 수 있는 곳으로, 다양한 토핑과 깊은 국물 맛이 일품입니다.\n\n5. **델리카한스 해운대점**: 브런치나 가벼운 식사를 원하신다면 이곳을 추천드립니다. 샌드위치와 베이커리가 맛있기로 유명합니다.\n\n이 외에도 해운대 주변에는 다양한 종류의 레스토랑들이 많이 있으니, 취향에 맞게 선택해서 즐기시면 좋을 것 같습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 297, 'prompt_tokens': 449, 'total_tokens': 746, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-Bfi5RX98T0sIWf9Dj7OlsNtWBvBNv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--be47f17d-2a84-4256-8e60-93ced8d2fc63-0' usage_metadata={'input_tokens': 449, 'output_tokens': 297, 'total_tokens': 746, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# ## langchain history 객체 이용하기

# %% [markdown]
# - pip install langchain_community

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-3.5-turbo-0125", api_key=api_key)
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000187E6CF6450>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000187E73EE660>, root_client=<openai.OpenAI object at 0x00000187E738AF30>, root_async_client=<openai.AsyncOpenAI object at 0x00000187E744C140>, model_name='gpt-3.5-turbo-0125', model_kwargs={}, openai_api_key=SecretStr('**********'))

# %%
from langchain.memory import ChatMessageHistory

history = ChatMessageHistory()
history.add_message(
    SystemMessage(content="당신은 서울의 음시과 문화 전문가 입니다.")
)
history.add_user_message("서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.")
response = llm.invoke(history.messages)

# %%
print(response)
# Out:
# content='서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해드리겠습니다.\n\n1. **명동 칼국수**: 명동에 위치한 이 곳은 한국 전통 음식 중 하나인 칼국수를 맛볼 수 있는 인기 레스토랑입니다. 싱싱한 면과 감자만두, 고기 등을 함께 즐길 수 있습니다.\n\n2. **고려원**: 인사동에 위치한 고려원은 전통적인 한식 요리를 맛볼 수 있는 곳으로 유명합니다. 계절별로 다양한 한정식 코스요리를 즐길 수 있습니다.\n\n3. **통인동 갈비집**: 통인시장 근처에 위치한 이 곳은 한국의 대표 음식인 갈비를 맛볼 수 있는 레스토랑입니다. 즉석에서 구워주는 고기와 함께 다양한 반찬을 즐길 수 있습니다.\n\n4. **이태원 테이스트 오브 인디아**: 이태원에 위치한 이 인도 음식 전문 레스토랑은 매콤하고 풍부한 맛이 특징입니다. 버터 치킨이나 살사 등 다양한 인도 요리를 즐길 수 있습니다.\n\n5. **광화문 세검정**: 광화문 근처에 위치한 이 레스토랑은 고급스러운 한정식을 맛볼 수 있는 곳으로 유명합니다. 전통적인 조리법과 재료를 사용하여 정갈한 맛을 경험할 수 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 492, 'prompt_tokens': 68, 'total_tokens': 560, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-Bfi81S15B2ds71kcFgOsmmI8GVj0F', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--d4f987d6-4782-4957-be5d-cb6f0febe591-0' usage_metadata={'input_tokens': 68, 'output_tokens': 492, 'total_tokens': 560, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(response.content)
# Out:
# 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해드리겠습니다.
#
# 1. **명동 칼국수**: 명동에 위치한 이 곳은 한국 전통 음식 중 하나인 칼국수를 맛볼 수 있는 인기 레스토랑입니다. 싱싱한 면과 감자만두, 고기 등을 함께 즐길 수 있습니다.
#
# 2. **고려원**: 인사동에 위치한 고려원은 전통적인 한식 요리를 맛볼 수 있는 곳으로 유명합니다. 계절별로 다양한 한정식 코스요리를 즐길 수 있습니다.
#
# 3. **통인동 갈비집**: 통인시장 근처에 위치한 이 곳은 한국의 대표 음식인 갈비를 맛볼 수 있는 레스토랑입니다. 즉석에서 구워주는 고기와 함께 다양한 반찬을 즐길 수 있습니다.
#
# 4. **이태원 테이스트 오브 인디아**: 이태원에 위치한 이 인도 음식 전문 레스토랑은 매콤하고 풍부한 맛이 특징입니다. 버터 치킨이나 살사 등 다양한 인도 요리를 즐길 수 있습니다.
#
# 5. **광화문 세검정**: 광화문 근처에 위치한 이 레스토랑은 고급스러운 한정식을 맛볼 수 있는 곳으로 유명합니다. 전통적인 조리법과 재료를 사용하여 정갈한 맛을 경험할 수 있습니다.

# %%
history.add_user_message("부산역에서 그곳에 가는 교통편을 알려주세요.")
response = llm.invoke(history.messages)
history.add_ai_message(response.content)
for message in history.messages:
    print(type(message), message)
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 서울의 음시과 문화 전문가 입니다.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해줘.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# <class 'langchain_core.messages.ai.AIMessage'> content='부산역에서 서울로 가는 교통수단은 기차, 버스, 비행기가 있습니다. \n1. 기차: KTX를 이용하면 부산역에서 서울역까지 빠르게 이동할 수 있습니다.\n2. 버스: 고속버스를 이용하면 부산에서 서울로 편리하게 이동할 수 있습니다. 주요 터미널은 서울 역삼터미널, 서울고속버스터미널, 동서울종합터미널 등이 있습니다.\n3. 비행기: 부산 김해공항 또는 부산 제주항구에서 비행기를 이용하여 서울까지 이동할 수도 있습니다.\n원하시는 교통수단에 맞춰 선택하시면 될 것 같습니다.' additional_kwargs={} response_metadata={}

# %% [markdown]
# # 토큰 수 확인하기

# %%
from langchain.callbacks import get_openai_callback

with get_openai_callback() as callback:
    message = [HumanMessage(content="서울역에 도착해서 서울에서 광장시장까지 가는 교통편 3개를 알려줘")]
    reaponse = llm.invoke(message)
    print(reaponse.content)
    print("-"*20)
    print(callback)
    print("-"*20)
    print(callback.total_tokens)
# Out:
# 1. 지하철 이용
# 서울역에서 광장시장까지 가는 가장 편리한 방법은 지하철을 이용하는 것입니다.
# 서울역에서 4호선을 타고 종로3가역까지 이동한 뒤, 환경부 앞역으로 이동하여 광장시장에 도착할 수 있습니다. 전체 소요시간은 약 20분 정도 소요됩니다.
#
# 2. 버스 이용
# 서울역 앞 버스 정류장에서 버스를 타고 광장시장에 도착할 수도 있습니다.
# 서울역에서 광장시장을 연결하는 버스 노선은 여러 개가 있으며, 버스를 이용하면 직접적으로 광장시장까지 이동할 수 있습니다. 전체 소요시간은 교통 상황에 따라 다를 수 있습니다.
#
# 3. 택시 이용
# 택시를 이용하여 서울역에서 광장시장까지 이동할 수도 있습니다. 택시를 이용하면 편리하고 빠르게 목적지에 도착할 수 있지만, 교통 상황에 따라 이동 시간이 달라질 수 있습니다. 전체 요금은 택시 요금표에 따라 다를 수 있습니다.
# --------------------
# Tokens Used: 435
# 	Prompt Tokens: 51
# 		Prompt Tokens Cached: 0
# 	Completion Tokens: 384
# 		Reasoning Tokens: 0
# Successful Requests: 1
# Total Cost (USD): $0.0006015
# --------------------
# 435
